# %%
# !sh run_en2ko.sh vocab
# Out:
# read in source sentences: ./en_es_data/train.en
# read in target sentences: ./en_es_data/train.ko
# initialize vocabulary ..
# number of word types: 54876, number of word types w/ frequency >= 1: 54876
# number of word types: 51800, number of word types w/ frequency >= 1: 51800
# generated vocabulary, vocs 106111 words
# vocabulary saved to vocab.json

# %%
with open('en_es_data/test_origin.ko','r') as f:
    ko = f.read().split('\n')
len(ko)
# Out:
# 9123

# %%
cp en_es_data/dev.* en_es_data/dev_orig

# %%
with open('en_es_data/test_base/test.ko','r') as f:
    X = f.read().split('\n')
with open('en_es_data/test.ko', 'w') as f:
    f.write('\n'.join(X[:10]))

# %%
cp en_es_data/dev_orig/* en_es_data

# %%
nR = 4
deN = 14
with open('train_CNN/new_data/en2ko/srcEn','r') as f:
    en = f.read().split('\n')
en = [s for i,s in enumerate(en) if i%deN == nR]
with open('en_es_data/srcE', 'w') as f:
    f.write('\n'.join(en))
    
with open('train_CNN/new_data/to_Train_0515/srcKo','r') as f:
    ko = f.read().split('\n')
ko = [s for i,s in enumerate(ko) if i%deN == nR]
with open('en_es_data/srcK', 'w') as f:
    f.write('\n'.join(ko))
            
with open('en_es_data/train_donot_change/train.en','r') as f:
    en = f.read().split('\n')
en = [s for i,s in enumerate(en) if i%deN == nR]
with open('en_es_data/train.en', 'w') as f:
    f.write('\n'.join(en))
            
with open('en_es_data/train_donot_change/train.ko','r') as f:
    ko = f.read().split('\n')
ko = [s for i,s in enumerate(ko) if i%deN == nR]
with open('en_es_data/train.ko', 'w') as f:
    f.write('\n'.join(ko))
            
with open('en_es_data/train.en','r') as f:
    X = f.read().split('\n')
len(X)
# Out:
# 61518

# %%
cp en_es_data/train_donot_change/* en_es_data

# %%
# !sh run_ko2en.sh test
# Out:
# load test source sentences from [./en_es_data/test.ko]
# load test target sentences from [./en_es_data/test.en]
# load model from model.bin
# Decoding: 100%|█████████████████████████████████| 10/10 [00:17<00:00,  1.74s/it]
# Corpus BLEU: 0

# %%
# !sh run_ko2en.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 100, avg. loss 149.50, avg. ppl 69.53 cum. examples 3200, speed 2203.24 words/sec, time elapsed 51.19 sec
# epoch 1, iter 200, avg. loss 130.13, avg. ppl 40.34 cum. examples 6400, speed 2242.76 words/sec, time elapsed 101.41 sec
# epoch 1, iter 300, avg. loss 130.02, avg. ppl 38.67 cum. examples 9600, speed 2328.47 words/sec, time elapsed 150.30 sec
# epoch 1, iter 400, avg. loss 127.92, avg. ppl 37.50 cum. examples 12800, speed 2339.50 words/sec, time elapsed 198.57 sec
# epoch 1, iter 500, avg. loss 125.50, avg. ppl 35.57 cum. examples 16000, speed 2288.53 words/sec, time elapsed 247.71 sec
# epoch 1, iter 600, avg. loss 123.57, avg. ppl 34.40 cum. examples 19200, speed 2291.90 words/sec, time elapsed 296.47 sec
# epoch 1, iter 700, avg. loss 123.66, avg. ppl 33.18 cum. examples 22400, speed 2319.25 words/sec, time elapsed 345.19 sec
# ...

# %%
# !sh run_en2en.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 100, avg. loss 87.42, avg. ppl 25.78 cum. examples 3200, speed 1914.21 words/sec, time elapsed 44.97 sec
# epoch 1, iter 200, avg. loss 62.64, avg. ppl 10.04 cum. examples 6400, speed 2088.80 words/sec, time elapsed 86.58 sec
# epoch 1, iter 300, avg. loss 59.75, avg. ppl 9.12 cum. examples 9600, speed 2054.04 words/sec, time elapsed 128.69 sec
# epoch 1, iter 400, avg. loss 58.06, avg. ppl 8.56 cum. examples 12800, speed 2025.89 words/sec, time elapsed 171.40 sec
# epoch 1, iter 500, avg. loss 55.68, avg. ppl 8.07 cum. examples 16000, speed 2067.49 words/sec, time elapsed 212.67 sec
# epoch 1, iter 600, avg. loss 55.76, avg. ppl 7.88 cum. examples 19200, speed 2023.14 words/sec, time elapsed 255.40 sec
# epoch 1, iter 700, avg. loss 54.87, avg. ppl 7.62 cum. examples 22400, speed 2042.82 words/sec, time elapsed 297.74 sec
# ...

# %%
# !sh run_en2ko.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 100, avg. loss 170.85, avg. ppl 29.34 cum. examples 3200, speed 2599.64 words/sec, time elapsed 62.24 sec
# epoch 1, iter 200, avg. loss 151.36, avg. ppl 20.15 cum. examples 6400, speed 2622.49 words/sec, time elapsed 123.73 sec
# epoch 1, iter 300, avg. loss 149.80, avg. ppl 18.98 cum. examples 9600, speed 2716.11 words/sec, time elapsed 183.69 sec
# epoch 1, iter 400, avg. loss 147.79, avg. ppl 18.33 cum. examples 12800, speed 2731.69 words/sec, time elapsed 243.22 sec
# epoch 1, iter 500, avg. loss 144.32, avg. ppl 17.56 cum. examples 16000, speed 2710.29 words/sec, time elapsed 302.68 sec
# epoch 1, iter 600, avg. loss 142.33, avg. ppl 16.91 cum. examples 19200, speed 2748.80 words/sec, time elapsed 361.27 sec
# epoch 1, iter 700, avg. loss 141.77, avg. ppl 16.46 cum. examples 22400, speed 2783.77 words/sec, time elapsed 419.45 sec
# ...

# %%
# !sh run_ko2ko.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 100, avg. loss 199.80, avg. ppl 26.26 cum. examples 3200, speed 2236.55 words/sec, time elapsed 87.47 sec
# epoch 1, iter 200, avg. loss 141.24, avg. ppl 10.21 cum. examples 6400, speed 2298.00 words/sec, time elapsed 172.14 sec
# epoch 1, iter 300, avg. loss 130.42, avg. ppl 8.36 cum. examples 9600, speed 2289.72 words/sec, time elapsed 257.99 sec
# epoch 1, iter 400, avg. loss 119.85, avg. ppl 7.30 cum. examples 12800, speed 2274.34 words/sec, time elapsed 342.84 sec
# epoch 1, iter 500, avg. loss 114.94, avg. ppl 6.75 cum. examples 16000, speed 2308.84 words/sec, time elapsed 426.25 sec
# epoch 1, iter 600, avg. loss 111.96, avg. ppl 6.29 cum. examples 19200, speed 2286.85 words/sec, time elapsed 511.45 sec
# epoch 1, iter 700, avg. loss 108.51, avg. ppl 5.99 cum. examples 22400, speed 2276.65 words/sec, time elapsed 596.67 sec
# ...

# %%
# !sh run_ko2en.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 100, avg. loss 166.80, avg. ppl 112.08 cum. examples 3200, speed 2277.24 words/sec, time elapsed 49.67 sec
# epoch 1, iter 200, avg. loss 144.74, avg. ppl 61.89 cum. examples 6400, speed 2354.66 words/sec, time elapsed 97.35 sec
# epoch 1, iter 300, avg. loss 143.44, avg. ppl 57.67 cum. examples 9600, speed 2287.81 words/sec, time elapsed 146.83 sec
# epoch 1, iter 400, avg. loss 140.29, avg. ppl 53.29 cum. examples 12800, speed 2319.52 words/sec, time elapsed 195.51 sec
# epoch 1, iter 500, avg. loss 139.07, avg. ppl 51.90 cum. examples 16000, speed 2310.19 words/sec, time elapsed 244.29 sec
# epoch 1, iter 600, avg. loss 136.19, avg. ppl 47.26 cum. examples 19200, speed 2323.85 words/sec, time elapsed 292.93 sec
# epoch 1, iter 700, avg. loss 135.40, avg. ppl 45.18 cum. examples 22400, speed 2312.76 words/sec, time elapsed 342.09 sec
# ...

# %%
# !sh run_en2en.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 100, avg. loss 102.08, avg. ppl 42.19 cum. examples 3200, speed 2002.53 words/sec, time elapsed 43.59 sec
# epoch 1, iter 200, avg. loss 72.48, avg. ppl 14.52 cum. examples 6400, speed 2023.30 words/sec, time elapsed 86.44 sec
# epoch 1, iter 300, avg. loss 66.94, avg. ppl 12.37 cum. examples 9600, speed 2053.68 words/sec, time elapsed 127.91 sec
# epoch 1, iter 400, avg. loss 65.11, avg. ppl 11.36 cum. examples 12800, speed 2126.68 words/sec, time elapsed 168.23 sec
# epoch 1, iter 500, avg. loss 62.91, avg. ppl 10.50 cum. examples 16000, speed 2097.14 words/sec, time elapsed 209.06 sec
# epoch 1, iter 600, avg. loss 63.04, avg. ppl 10.23 cum. examples 19200, speed 2026.73 words/sec, time elapsed 251.86 sec
# epoch 1, iter 700, avg. loss 59.92, avg. ppl 9.43 cum. examples 22400, speed 2052.74 words/sec, time elapsed 293.48 sec
# ...

# %%
# !sh run_en2ko.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 100, avg. loss 182.66, avg. ppl 37.85 cum. examples 3200, speed 2585.50 words/sec, time elapsed 62.22 sec
# epoch 1, iter 200, avg. loss 168.89, avg. ppl 28.15 cum. examples 6400, speed 2706.17 words/sec, time elapsed 122.06 sec
# epoch 1, iter 300, avg. loss 165.18, avg. ppl 25.73 cum. examples 9600, speed 2771.39 words/sec, time elapsed 180.78 sec
# epoch 1, iter 400, avg. loss 161.48, avg. ppl 24.30 cum. examples 12800, speed 2755.78 words/sec, time elapsed 239.56 sec
# epoch 1, iter 500, avg. loss 158.06, avg. ppl 22.93 cum. examples 16000, speed 2772.43 words/sec, time elapsed 297.79 sec
# epoch 1, iter 600, avg. loss 155.41, avg. ppl 21.78 cum. examples 19200, speed 2776.08 words/sec, time elapsed 355.94 sec
# epoch 1, iter 700, avg. loss 154.54, avg. ppl 21.02 cum. examples 22400, speed 2800.36 words/sec, time elapsed 413.93 sec
# ...

# %%
# !sh run_ko2ko.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 100, avg. loss 253.42, avg. ppl 64.08 cum. examples 3200, speed 2199.74 words/sec, time elapsed 88.62 sec
# epoch 1, iter 200, avg. loss 204.99, avg. ppl 29.23 cum. examples 6400, speed 2301.49 words/sec, time elapsed 173.06 sec
# epoch 1, iter 300, avg. loss 178.71, avg. ppl 19.30 cum. examples 9600, speed 2299.25 words/sec, time elapsed 257.09 sec
# epoch 1, iter 400, avg. loss 163.29, avg. ppl 14.71 cum. examples 12800, speed 2292.87 words/sec, time elapsed 341.86 sec
# epoch 1, iter 500, avg. loss 155.66, avg. ppl 13.19 cum. examples 16000, speed 2282.68 words/sec, time elapsed 426.46 sec
# epoch 1, iter 600, avg. loss 147.93, avg. ppl 11.44 cum. examples 19200, speed 2304.10 words/sec, time elapsed 510.77 sec
# epoch 1, iter 700, avg. loss 139.30, avg. ppl 9.93 cum. examples 22400, speed 2282.24 words/sec, time elapsed 595.84 sec
# ...

# %%
# !sh run_ko2en.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 100, avg. loss 186.15, avg. ppl 203.08 cum. examples 3200, speed 2234.13 words/sec, time elapsed 50.18 sec
# epoch 1, iter 200, avg. loss 167.66, avg. ppl 120.59 cum. examples 6400, speed 2346.30 words/sec, time elapsed 97.89 sec
# epoch 1, iter 300, avg. loss 167.69, avg. ppl 111.64 cum. examples 9600, speed 2307.56 words/sec, time elapsed 147.21 sec
# epoch 1, iter 400, avg. loss 160.10, avg. ppl 97.03 cum. examples 12800, speed 2328.25 words/sec, time elapsed 195.30 sec
# epoch 1, iter 500, avg. loss 161.42, avg. ppl 95.35 cum. examples 16000, speed 2319.53 words/sec, time elapsed 244.17 sec
# epoch 1, iter 600, avg. loss 156.73, avg. ppl 86.36 cum. examples 19200, speed 2311.69 words/sec, time elapsed 292.83 sec
# epoch 1, iter 700, avg. loss 155.70, avg. ppl 85.34 cum. examples 22400, speed 2339.66 words/sec, time elapsed 340.72 sec
# ...

# %%
# !sh run_en2en.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 100, avg. loss 110.68, avg. ppl 63.64 cum. examples 3200, speed 1945.36 words/sec, time elapsed 43.84 sec
# epoch 1, iter 200, avg. loss 87.35, avg. ppl 24.56 cum. examples 6400, speed 2128.66 words/sec, time elapsed 84.86 sec
# epoch 1, iter 300, avg. loss 82.99, avg. ppl 21.51 cum. examples 9600, speed 2100.81 words/sec, time elapsed 126.05 sec
# epoch 1, iter 400, avg. loss 76.68, avg. ppl 18.27 cum. examples 12800, speed 2081.82 words/sec, time elapsed 166.62 sec
# epoch 1, iter 500, avg. loss 76.56, avg. ppl 17.36 cum. examples 16000, speed 2067.99 words/sec, time elapsed 208.13 sec
# epoch 1, iter 600, avg. loss 75.19, avg. ppl 15.72 cum. examples 19200, speed 2076.69 words/sec, time elapsed 250.18 sec
# epoch 1, iter 700, avg. loss 70.66, avg. ppl 14.27 cum. examples 22400, speed 2079.57 words/sec, time elapsed 291.09 sec
# ...

# %%
# !sh run_en2ko.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 100, avg. loss 225.19, avg. ppl 86.79 cum. examples 3200, speed 2682.20 words/sec, time elapsed 60.19 sec
# epoch 1, iter 200, avg. loss 188.30, avg. ppl 42.48 cum. examples 6400, speed 2776.33 words/sec, time elapsed 118.08 sec
# epoch 1, iter 300, avg. loss 187.40, avg. ppl 39.71 cum. examples 9600, speed 2742.18 words/sec, time elapsed 177.48 sec
# epoch 1, iter 400, avg. loss 181.50, avg. ppl 36.77 cum. examples 12800, speed 2703.95 words/sec, time elapsed 237.07 sec
# epoch 1, iter 500, avg. loss 181.23, avg. ppl 35.76 cum. examples 16000, speed 2744.16 words/sec, time elapsed 296.16 sec
# epoch 1, iter 600, avg. loss 176.29, avg. ppl 33.37 cum. examples 19200, speed 2717.83 words/sec, time elapsed 355.33 sec
# epoch 1, iter 700, avg. loss 175.29, avg. ppl 32.03 cum. examples 22400, speed 2742.21 words/sec, time elapsed 414.34 sec
# ...

# %%
# !sh run_en2en.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 100, avg. loss 156.39, avg. ppl 331.48 cum. examples 3200, speed 1986.37 words/sec, time elapsed 43.41 sec
# epoch 1, iter 200, avg. loss 146.68, avg. ppl 215.98 cum. examples 6400, speed 2039.25 words/sec, time elapsed 86.23 sec
# epoch 1, iter 300, avg. loss 131.57, avg. ppl 131.95 cum. examples 9600, speed 2052.83 words/sec, time elapsed 128.24 sec
# epoch 1, iter 400, avg. loss 117.82, avg. ppl 81.86 cum. examples 12800, speed 2018.81 words/sec, time elapsed 170.63 sec
# epoch 1, iter 500, avg. loss 109.46, avg. ppl 57.92 cum. examples 16000, speed 2047.37 words/sec, time elapsed 212.78 sec
# epoch 1, iter 600, avg. loss 100.05, avg. ppl 43.30 cum. examples 19200, speed 2063.16 words/sec, time elapsed 253.96 sec
# epoch 1, iter 700, avg. loss 92.92, avg. ppl 34.50 cum. examples 22400, speed 2047.56 words/sec, time elapsed 294.98 sec
# ...

# %%
# !sh run_ko2en.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 100, avg. loss 249.07, avg. ppl 1168.38 cum. examples 3200, speed 2196.42 words/sec, time elapsed 51.37 sec
# epoch 1, iter 200, avg. loss 219.33, avg. ppl 499.19 cum. examples 6400, speed 2263.81 words/sec, time elapsed 101.28 sec
# epoch 1, iter 300, avg. loss 208.48, avg. ppl 374.09 cum. examples 9600, speed 2282.69 words/sec, time elapsed 150.60 sec
# epoch 1, iter 400, avg. loss 203.47, avg. ppl 322.11 cum. examples 12800, speed 2252.68 words/sec, time elapsed 200.65 sec
# epoch 1, iter 500, avg. loss 198.23, avg. ppl 288.74 cum. examples 16000, speed 2327.50 words/sec, time elapsed 248.76 sec
# epoch 1, iter 600, avg. loss 195.64, avg. ppl 255.78 cum. examples 19200, speed 2302.98 words/sec, time elapsed 297.79 sec
# epoch 1, iter 700, avg. loss 192.89, avg. ppl 238.09 cum. examples 22400, speed 2394.20 words/sec, time elapsed 344.90 sec
# ...

# %%
# !sh run_en2ko.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 100, avg. loss 241.55, avg. ppl 115.64 cum. examples 3200, speed 2332.39 words/sec, time elapsed 69.76 sec
# epoch 1, iter 200, avg. loss 220.57, avg. ppl 77.63 cum. examples 6400, speed 2684.14 words/sec, time elapsed 130.19 sec
# epoch 1, iter 200, cum. loss 231.06, cum. ppl 94.78 cum. examples 6400
# begin validation ...
# validation: iter 200, dev. ppl 65.147322
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 1, iter 300, avg. loss 211.13, avg. ppl 64.42 cum. examples 3200, speed 2014.44 words/sec, time elapsed 210.70 sec
# epoch 1, iter 400, avg. loss 205.40, avg. ppl 58.68 cum. examples 6400, speed 2724.13 words/sec, time elapsed 269.96 sec
# epoch 1, iter 400, cum. loss 208.27, cum. ppl 61.49 cum. examples 6400
# begin validation ...
# validation: iter 400, dev. ppl 53.263017
# ...

# %%
# !sh run_en2en.sh test
# Out:
# load test source sentences from [./en_es_data/test.en]
# load test target sentences from [./en_es_data/test.en]
# load model from model.bin
# Decoding: 100%|█████████████████████████████████| 10/10 [00:25<00:00,  2.54s/it]
# Corpus BLEU: 0

# %%
# !sh run_en2en.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cpu
# begin Maximum Likelihood training
# epoch 1, iter 20, avg. loss 203.19, avg. ppl 2343.03 cum. examples 80, speed 48.26 words/sec, time elapsed 43.41 sec
# epoch 1, iter 40, avg. loss 191.14, avg. ppl 936.00 cum. examples 160, speed 52.98 words/sec, time elapsed 85.60 sec
# epoch 1, iter 60, avg. loss 174.99, avg. ppl 746.92 cum. examples 240, speed 51.57 words/sec, time elapsed 126.63 sec
# epoch 1, iter 80, avg. loss 188.14, avg. ppl 778.20 cum. examples 320, speed 53.15 words/sec, time elapsed 169.17 sec
# epoch 1, iter 100, avg. loss 172.27, avg. ppl 721.47 cum. examples 400, speed 51.11 words/sec, time elapsed 210.14 sec
# epoch 1, iter 100, cum. loss 185.95, cum. ppl 978.74 cum. examples 400
# begin validation ...
# validation: iter 100, dev. ppl 1391.268657
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# ...

# %%
# !sh run_en2en.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cpu
# begin Maximum Likelihood training
# epoch 1, iter 10, avg. loss 215.58, avg. ppl 3760.07 cum. examples 80, speed 63.49 words/sec, time elapsed 32.99 sec
# epoch 1, iter 20, avg. loss 224.41, avg. ppl 3079.37 cum. examples 160, speed 74.02 words/sec, time elapsed 63.19 sec
# epoch 1, iter 30, avg. loss 201.44, avg. ppl 2030.34 cum. examples 240, speed 68.66 words/sec, time elapsed 94.01 sec
# epoch 1, iter 40, avg. loss 214.51, avg. ppl 1977.96 cum. examples 320, speed 72.94 words/sec, time elapsed 125.00 sec
# epoch 1, iter 50, avg. loss 194.88, avg. ppl 1711.82 cum. examples 400, speed 71.76 words/sec, time elapsed 154.18 sec
# epoch 1, iter 60, avg. loss 199.47, avg. ppl 1743.45 cum. examples 480, speed 71.92 words/sec, time elapsed 183.91 sec
# epoch 1, iter 70, avg. loss 210.78, avg. ppl 1479.81 cum. examples 560, speed 70.71 words/sec, time elapsed 216.58 sec
# ...

# %%
# !sh run_ko2en.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cpu
# begin Maximum Likelihood training
# epoch 1, iter 10, avg. loss 430.35, avg. ppl 204005.00 cum. examples 20, speed 37.14 words/sec, time elapsed 18.95 sec
# epoch 1, iter 20, avg. loss 373.36, avg. ppl 22844.21 cum. examples 40, speed 42.76 words/sec, time elapsed 36.35 sec
# epoch 1, iter 30, avg. loss 307.98, avg. ppl 5647.35 cum. examples 60, speed 41.74 words/sec, time elapsed 53.43 sec
# epoch 1, iter 40, avg. loss 339.60, avg. ppl 3279.00 cum. examples 80, speed 45.66 words/sec, time elapsed 71.81 sec
# epoch 1, iter 50, avg. loss 264.50, avg. ppl 4094.85 cum. examples 100, speed 38.21 words/sec, time elapsed 88.45 sec
# epoch 1, iter 60, avg. loss 278.20, avg. ppl 3330.33 cum. examples 120, speed 41.03 words/sec, time elapsed 105.17 sec
# epoch 1, iter 70, avg. loss 302.24, avg. ppl 2906.37 cum. examples 140, speed 43.83 words/sec, time elapsed 122.46 sec
# ...

# %%
# !sh run_en2ko.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cpu
# begin Maximum Likelihood training
# epoch 1, iter 20, avg. loss 309.86, avg. ppl 311.29 cum. examples 80, speed 75.05 words/sec, time elapsed 57.53 sec
# epoch 1, iter 40, avg. loss 236.07, avg. ppl 117.82 cum. examples 160, speed 74.26 words/sec, time elapsed 110.86 sec
# epoch 1, iter 60, avg. loss 226.08, avg. ppl 112.70 cum. examples 240, speed 74.59 words/sec, time elapsed 162.19 sec
# epoch 1, iter 80, avg. loss 234.11, avg. ppl 124.69 cum. examples 320, speed 75.80 words/sec, time elapsed 213.39 sec
# epoch 1, iter 100, avg. loss 242.46, avg. ppl 106.41 cum. examples 400, speed 77.21 words/sec, time elapsed 267.21 sec
# epoch 1, iter 100, cum. loss 249.72, cum. ppl 142.43 cum. examples 400
# begin validation ...
# validation: iter 100, dev. ppl 136.869620
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# ...

# %%
# !sh run_en2ko.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cpu
# begin Maximum Likelihood training
# epoch 1, iter 4, avg. loss 641.38, avg. ppl 55114.01 cum. examples 8, speed 44.57 words/sec, time elapsed 10.54 sec
# epoch 1, iter 8, avg. loss 454.72, avg. ppl 7784.75 cum. examples 16, speed 52.63 words/sec, time elapsed 18.26 sec
# epoch 1, iter 12, avg. loss 388.91, avg. ppl 5532.50 cum. examples 24, speed 44.52 words/sec, time elapsed 26.37 sec
# epoch 1, iter 16, avg. loss 427.10, avg. ppl 2316.51 cum. examples 32, speed 56.07 words/sec, time elapsed 34.23 sec
# epoch 1, iter 20, avg. loss 396.01, avg. ppl 1697.47 cum. examples 40, speed 53.99 words/sec, time elapsed 42.12 sec
# epoch 1, iter 24, avg. loss 416.92, avg. ppl 983.60 cum. examples 48, speed 58.40 words/sec, time elapsed 50.41 sec
# epoch 1, iter 28, avg. loss 310.12, avg. ppl 912.14 cum. examples 56, speed 47.28 words/sec, time elapsed 58.11 sec
# ...

# %%
ls -l
# Out:
# total 3176
# -rw-r--r-- 1 jupyter jupyter      98 May 26 13:27 collect_submission.sh
# -rw-r--r-- 1 jupyter jupyter   25969 May 26 13:27 data_preprocessing.ipynb
# -rw-r--r-- 1 jupyter jupyter    2415 May 26 13:27 data_to_test.txt
# drwxr-xr-x 7 jupyter jupyter    4096 May 29 01:29 en_es_data/
# -rw-r--r-- 1 jupyter jupyter      25 May 26 13:27 gpu_requirements.txt
# -rw-r--r-- 1 jupyter jupyter       0 May 26 13:28 __init__.py
# -rw-r--r-- 1 jupyter jupyter     157 May 26 13:27 local_env.yml
# -rw-r--r-- 1 jupyter jupyter    2062 May 26 13:27 model_embeddings_orig.py
# -rw------- 1 jupyter jupyter    2251 May 26 14:51 model_embeddings.py
# -rw------- 1 jupyter jupyter   39268 May 26 15:09 nmt_model_old.py
# -rw-r--r-- 1 jupyter jupyter   27471 May 26 13:27 nmt_model_orig.py
# -rw-r--r-- 1 jupyter jupyter   49427 May 28 16:07 nmt_model.py
# -rw-r--r-- 1 jupyter jupyter   42144 May 28 08:18 nmt_model_share_vocs_v1.py
# drwxr-xr-x 3 jupyter jupyter    4096 May 29 01:46 outputs/
# ...

# %%
# !sh run_en2ko.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cpu
# begin Maximum Likelihood training
# epoch 1, iter 4, avg. loss 349.55, avg. ppl 201038.08 cum. examples 16, speed 46.54 words/sec, time elapsed 9.84 sec
# epoch 1, iter 8, avg. loss 377.12, avg. ppl 79096.25 cum. examples 32, speed 61.36 words/sec, time elapsed 18.56 sec
# epoch 1, iter 12, avg. loss 354.30, avg. ppl 25360.84 cum. examples 48, speed 62.64 words/sec, time elapsed 27.49 sec
# epoch 1, iter 16, avg. loss 294.77, avg. ppl 8540.08 cum. examples 64, speed 56.42 words/sec, time elapsed 36.72 sec
# epoch 1, iter 20, avg. loss 321.40, avg. ppl 5200.64 cum. examples 80, speed 60.20 words/sec, time elapsed 46.70 sec
# epoch 1, iter 20, cum. loss 339.43, cum. ppl 25718.21 cum. examples 80
# begin validation ...
# validation: iter 20, dev. ppl 3637.344783
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# ...

# %%
# !sh run_en2ko.sh train

# %%
# !sh run_en2ko.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cpu
# begin Maximum Likelihood training
# /home/jupyter/Project/nmt_a4_enko_cnn_main_test/nmt_model.py:203: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X = torch.tensor(X,device = self.device)
# epoch 1, iter 4, avg. loss 471.05, avg. ppl 53711.70 cum. examples 16, speed 56.17 words/sec, time elapsed 12.32 sec
# epoch 1, iter 8, avg. loss 458.26, avg. ppl 6578.58 cum. examples 32, speed 75.55 words/sec, time elapsed 23.36 sec
# epoch 1, iter 12, avg. loss 403.26, avg. ppl 3560.55 cum. examples 48, speed 73.03 words/sec, time elapsed 34.16 sec
# epoch 1, iter 16, avg. loss 375.59, avg. ppl 1936.42 cum. examples 64, speed 68.17 words/sec, time elapsed 45.81 sec
# ...

# %%
471.05, avg. ppl 53711.70 c

# %%
# !sh run_en2ko.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cpu
# begin Maximum Likelihood training
# epoch 1, iter 4, avg. loss 354.29, avg. ppl 3610.76 cum. examples 16, speed 60.42 words/sec, time elapsed 11.45 sec
# epoch 1, iter 8, avg. loss 293.72, avg. ppl 280.03 cum. examples 32, speed 76.45 words/sec, time elapsed 22.36 sec
# epoch 1, iter 12, avg. loss 216.61, avg. ppl 80.86 cum. examples 48, speed 74.45 words/sec, time elapsed 32.96 sec
# epoch 1, iter 16, avg. loss 211.90, avg. ppl 71.52 cum. examples 64, speed 68.15 words/sec, time elapsed 44.61 sec
# epoch 1, iter 20, avg. loss 203.51, avg. ppl 62.64 cum. examples 80, speed 71.24 words/sec, time elapsed 55.66 sec
# epoch 1, iter 20, cum. loss 256.01, cum. ppl 191.86 cum. examples 80
# begin validation ...
# validation: iter 20, dev. ppl 152.164024
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# ...

# %%
# !sh run_en2ko.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# /home/jupyter/Project/nmt_a4_enko_cnn_main_test/nmt_model.py:300: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   XO = torch.tensor(pad_sequence(XO),device = self.device)
# epoch 1, iter 100, avg. loss 287.92, avg. ppl 291.06 cum. examples 3200, speed 3368.68 words/sec, time elapsed 48.21 sec
# epoch 1, iter 200, avg. loss 244.14, avg. ppl 118.45 cum. examples 6400, speed 3524.00 words/sec, time elapsed 94.64 sec
# epoch 1, iter 300, avg. loss 228.47, avg. ppl 91.08 cum. examples 9600, speed 3559.63 words/sec, time elapsed 140.16 sec
# epoch 1, iter 400, avg. loss 221.29, avg. ppl 78.44 cum. examples 12800, speed 3477.34 words/sec, time elapsed 186.85 sec
# ...
